# %%
# To make data frames
import pandas as pd

# To list files in a directory
import os
# Move up in directories
print(os.getcwd()) # for debugging
os.chdir("..")
print(os.getcwd()) # for debugging

# To work with .json files
import json

# To parse dates
from datetime import datetime
# Out:
# C:\Users\leyjf\Dropbox\github\FitbitStatsProject\CleanedData
# C:\Users\leyjf\Dropbox\github\FitbitStatsProject

# %% [markdown]
# # Exercise

# %%
# List of files using os
raw_exercise_files_path = "RawData\RawExerciseFiles"
raw_exercise_files_list = os.listdir(raw_exercise_files_path)
#print(raw_exercise_files_list) # for debugging        

all_extracted_data = []
for file in raw_exercise_files_list:
    # with is a more efficient way of reading files
    with open(raw_exercise_files_path+"\\"+file) as file:
        parsed_file = json.load(file)
    # Extract the data I want
    for entry in parsed_file:
        #print(entry) # for debugging
        if entry["activityName"]!="Weights":
            if entry["averageHeartRate"]>134: 
                activityName = "Run"
            else: 
                activityName = "Walk"
            extracted_data = {
                "activityName" : activityName,
                "averageHeartRate" : entry["averageHeartRate"],
                "belowZonesMinutes": entry["heartRateZones"][0]["minutes"],
                "fatBurnMinutes": entry["heartRateZones"][1]["minutes"],
                "cardioMinutes": entry["heartRateZones"][2]["minutes"],
                "peakMinutes" : entry["heartRateZones"][3]["minutes"],
                "startTime": entry["startTime"]
                } 
            # Append the list
            all_extracted_data.append(extracted_data)
#print(type(all_extracted_data)) # for debugging
#print(all_extracted_data) # for debugging
# Change to a json string    
all_extracted_data_string = json.dumps(all_extracted_data)
#print(all_extracted_data_string) # for debugging
all_extracted_data_json = json.loads(all_extracted_data_string)
#print(all_extracted_data_json) # for debugging

# Now group the extracted data by date
grouped_by_date = []
for i in range(len(all_extracted_data)):
    #print(all_extracted_data[i]) # for debugging
    date = all_extracted_data[i]["startTime"].split()[0]
    #print(date) # for debugging
    if i == 0 or date != all_extracted_data[i-1]["startTime"].split()[0]:
        j = 1
        exercise = {
            "date" : date,
            "exercise"+str(j) : all_extracted_data[i]
        }
        j = j + 1
    else: 
        exercise["exercise"+str(j)] = all_extracted_data[i]
        j = j + 1
    if i < len(all_extracted_data)-1 and date != all_extracted_data[i+1]["startTime"].split()[0]:    
        #print(date) # for debugging
        #print(all_extracted_data[i+1]["startTime"].split()[0]) # for debugging
        grouped_by_date.append(exercise)
    elif i == len(all_extracted_data)-1:
        grouped_by_date.append(exercise)
#print(grouped_by_date) # for debugging    

# Total exercise per day
for day in grouped_by_date:
    total_minutes = 0
    for i in range(1,len(day)):
        total_minutes = sum((day["exercise"+str(i)]["belowZonesMinutes"],
                            day["exercise"+str(i)]["fatBurnMinutes"],
                            day["exercise"+str(i)]["cardioMinutes"],
                            day["exercise"+str(i)]["peakMinutes"]),
                            total_minutes)
    day["totalMinutes"] = total_minutes    
#parsed_exercise # for debugging 

# Month for each day
for day in grouped_by_date:
    month_year = datetime.strptime(day["date"], "%m/%d/%y").strftime('%B %Y')
    day["month"] = month_year

# Save parsed string to a .json file
grouped_by_date_string = json.dumps(grouped_by_date)
grouped_by_date_json = json.loads(grouped_by_date_string)
save_file = open("CleanedData\\exercise_grouped_by_date.json", "w")  
json.dump(grouped_by_date_json, save_file, indent = 4)  
save_file.close()

# %% [markdown]
# # Resting heart rate

# %%
# List of files using os
raw_heart_rate_files_path = "RawData\RawHeartRateFiles"
raw_heart_rate_files_list = os.listdir(raw_heart_rate_files_path)
 
resting_heart_rate_data = []
# Can't use list comprehension with extend function(?)
for file in raw_heart_rate_files_list:
    # with is a more efficient way of reading files
    with open(raw_heart_rate_files_path+"\\"+file) as file:
        parsed_file = json.load(file)
    resting_hr = min([entry["value"]["bpm"] for entry in parsed_file])    
    #print("Resting hr is "+str(resting_hr)+".") # for debugging
    new_dict = {
        "date" : parsed_file[0]["dateTime"].split()[0],
        "resting_hr" : resting_hr
        }
    #print(new_dict) # for debugging
    resting_heart_rate_data.append(new_dict)    

# Change to a json string    
resting_heart_rate_data_string = json.dumps(resting_heart_rate_data)

# Save parsed string to a .json file
save_file = open("CleanedData\\resting_hr_cleaned.json", "w")  
json.dump(json.loads(resting_heart_rate_data_string), save_file, indent = 4)  
save_file.close()
# Out:
# Resting hr is 57.
# {'date': '03/14/22', 'resting_hr': 57}
# Resting hr is 44.
# {'date': '03/15/22', 'resting_hr': 44}
# Resting hr is 49.
# {'date': '03/16/22', 'resting_hr': 49}
# Resting hr is 54.
# {'date': '03/17/22', 'resting_hr': 54}
# Resting hr is 51.
# {'date': '03/18/22', 'resting_hr': 51}
# Resting hr is 55.
# {'date': '03/19/22', 'resting_hr': 55}
# Resting hr is 55.
# {'date': '03/20/22', 'resting_hr': 55}
# Resting hr is 50.
# {'date': '03/21/22', 'resting_hr': 50}
# Resting hr is 53.
# {'date': '03/22/22', 'resting_hr': 53}
# Resting hr is 51.
# {'date': '03/23/22', 'resting_hr': 51}
# Resting hr is 60.
# {'date': '03/24/22', 'resting_hr': 60}
# Resting hr is 51.
# {'date': '03/25/22', 'resting_hr': 51}
# Resting hr is 50.
# {'date': '03/26/22', 'resting_hr': 50}
# Resting hr is 44.
# {'date': '03/27/22', 'resting_hr': 44}
# Resting hr is 56.
# {'date': '03/28/22', 'resting_hr': 56}
# Resting hr is 52.
# {'date': '03/29/22', 'resting_hr': 52}
# Resting hr is 48.
# {'date': '03/30/22', 'resting_hr': 48}
# Resting hr is 51.
# {'date': '03/31/22', 'resting_hr': 51}
# Resting hr is 48.
# {'date': '04/01/22', 'resting_hr': 48}
# Resting hr is 50.
# {'date': '04/02/22', 'resting_hr': 50}
# Resting hr is 51.
# {'date': '04/03/22', 'resting_hr': 51}
# Resting hr is 47.
# {'date': '04/04/22', 'resting_hr': 47}
# Resting hr is 55.
# {'date': '04/05/22', 'resting_hr': 55}
# Resting hr is 46.
# {'date': '04/06/22', 'resting_hr': 46}
# Resting hr is 50.
# {'date': '04/07/22', 'resting_hr': 50}
# Resting hr is 48.
# {'date': '04/08/22', 'resting_hr': 48}
# Resting hr is 52.
# {'date': '04/09/22', 'resting_hr': 52}
# Resting hr is 49.
# {'date': '04/10/22', 'resting_hr': 49}
# Resting hr is 52.
# {'date': '04/11/22', 'resting_hr': 52}
# Resting hr is 58.
# {'date': '04/12/22', 'resting_hr': 58}
# Resting hr is 56.
# {'date': '04/13/22', 'resting_hr': 56}
# Resting hr is 48.
# {'date': '04/14/22', 'resting_hr': 48}
# Resting hr is 55.
# {'date': '04/15/22', 'resting_hr': 55}
# Resting hr is 56.
# {'date': '04/16/22', 'resting_hr': 56}
# Resting hr is 51.
# {'date': '04/17/22', 'resting_hr': 51}
# Resting hr is 49.
# {'date': '04/18/22', 'resting_hr': 49}
# Resting hr is 51.
# {'date': '04/19/22', 'resting_hr': 51}
# Resting hr is 47.
# {'date': '04/20/22', 'resting_hr': 47}
# Resting hr is 52.
# {'date': '04/21/22', 'resting_hr': 52}
# Resting hr is 48.
# {'date': '04/22/22', 'resting_hr': 48}
# Resting hr is 53.
# {'date': '04/23/22', 'resting_hr': 53}
# Resting hr is 48.
# {'date': '04/24/22', 'resting_hr': 48}
# Resting hr is 45.
# {'date': '04/25/22', 'resting_hr': 45}
# Resting hr is 59.
# {'date': '04/26/22', 'resting_hr': 59}
# Resting hr is 47.
# {'date': '04/27/22', 'resting_hr': 47}
# Resting hr is 47.
# {'date': '04/28/22', 'resting_hr': 47}
# Resting hr is 46.
# {'date': '04/29/22', 'resting_hr': 46}
# Resting hr is 48.
# {'date': '04/30/22', 'resting_hr': 48}
# Resting hr is 52.
# {'date': '05/01/22', 'resting_hr': 52}
# Resting hr is 52.
# {'date': '05/02/22', 'resting_hr': 52}
# Resting hr is 46.
# {'date': '05/03/22', 'resting_hr': 46}
# Resting hr is 47.
# {'date': '05/04/22', 'resting_hr': 47}
# Resting hr is 48.
# {'date': '05/05/22', 'resting_hr': 48}
# Resting hr is 57.
# {'date': '05/06/22', 'resting_hr': 57}
# Resting hr is 48.
# {'date': '05/07/22', 'resting_hr': 48}
# Resting hr is 49.
# {'date': '05/08/22', 'resting_hr': 49}
# Resting hr is 46.
# {'date': '05/09/22', 'resting_hr': 46}
# Resting hr is 52.
# {'date': '05/10/22', 'resting_hr': 52}
# Resting hr is 50.
# {'date': '05/11/22', 'resting_hr': 50}
# Resting hr is 51.
# {'date': '05/12/22', 'resting_hr': 51}
# Resting hr is 51.
# {'date': '05/13/22', 'resting_hr': 51}
# Resting hr is 51.
# {'date': '05/14/22', 'resting_hr': 51}
# Resting hr is 51.
# {'date': '05/15/22', 'resting_hr': 51}
# Resting hr is 43.
# {'date': '05/16/22', 'resting_hr': 43}
# Resting hr is 54.
# {'date': '05/17/22', 'resting_hr': 54}
# Resting hr is 48.
# {'date': '05/18/22', 'resting_hr': 48}
# Resting hr is 48.
# {'date': '05/19/22', 'resting_hr': 48}
# Resting hr is 52.
# {'date': '05/20/22', 'resting_hr': 52}
# Resting hr is 48.
# {'date': '05/21/22', 'resting_hr': 48}
# Resting hr is 48.
# {'date': '05/22/22', 'resting_hr': 48}
# Resting hr is 51.
# {'date': '05/23/22', 'resting_hr': 51}
# Resting hr is 42.
# {'date': '05/24/22', 'resting_hr': 42}
# Resting hr is 46.
# {'date': '05/25/22', 'resting_hr': 46}
# Resting hr is 49.
# {'date': '05/26/22', 'resting_hr': 49}
# Resting hr is 49.
# {'date': '05/27/22', 'resting_hr': 49}
# Resting hr is 61.
# {'date': '05/28/22', 'resting_hr': 61}
# Resting hr is 50.
# {'date': '05/29/22', 'resting_hr': 50}
# Resting hr is 48.
# {'date': '05/30/22', 'resting_hr': 48}
# Resting hr is 47.
# {'date': '05/31/22', 'resting_hr': 47}
# Resting hr is 53.
# {'date': '06/01/22', 'resting_hr': 53}
# Resting hr is 48.
# {'date': '06/02/22', 'resting_hr': 48}
# Resting hr is 51.
# {'date': '06/03/22', 'resting_hr': 51}
# Resting hr is 48.
# {'date': '06/04/22', 'resting_hr': 48}
# Resting hr is 49.
# {'date': '06/05/22', 'resting_hr': 49}
# Resting hr is 56.
# {'date': '06/06/22', 'resting_hr': 56}
# Resting hr is 51.
# {'date': '06/07/22', 'resting_hr': 51}
# Resting hr is 55.
# {'date': '06/08/22', 'resting_hr': 55}
# Resting hr is 48.
# {'date': '06/09/22', 'resting_hr': 48}
# Resting hr is 46.
# {'date': '06/10/22', 'resting_hr': 46}
# Resting hr is 51.
# {'date': '06/11/22', 'resting_hr': 51}
# Resting hr is 48.
# {'date': '06/12/22', 'resting_hr': 48}
# Resting hr is 50.
# {'date': '06/13/22', 'resting_hr': 50}
# Resting hr is 46.
# {'date': '06/14/22', 'resting_hr': 46}
# Resting hr is 44.
# {'date': '06/15/22', 'resting_hr': 44}
# Resting hr is 44.
# {'date': '06/16/22', 'resting_hr': 44}
# Resting hr is 41.
# {'date': '06/17/22', 'resting_hr': 41}
# Resting hr is 43.
# {'date': '06/18/22', 'resting_hr': 43}
# Resting hr is 46.
# {'date': '06/19/22', 'resting_hr': 46}
# Resting hr is 43.
# {'date': '06/20/22', 'resting_hr': 43}
# Resting hr is 43.
# {'date': '06/21/22', 'resting_hr': 43}
# Resting hr is 44.
# {'date': '06/22/22', 'resting_hr': 44}
# Resting hr is 42.
# {'date': '06/23/22', 'resting_hr': 42}
# Resting hr is 50.
# {'date': '06/24/22', 'resting_hr': 50}
# Resting hr is 47.
# {'date': '06/25/22', 'resting_hr': 47}
# Resting hr is 45.
# {'date': '06/26/22', 'resting_hr': 45}
# Resting hr is 49.
# {'date': '06/27/22', 'resting_hr': 49}
# Resting hr is 48.
# {'date': '06/28/22', 'resting_hr': 48}
# Resting hr is 50.
# {'date': '06/29/22', 'resting_hr': 50}
# Resting hr is 49.
# {'date': '06/30/22', 'resting_hr': 49}
# Resting hr is 49.
# {'date': '07/01/22', 'resting_hr': 49}
# Resting hr is 52.
# {'date': '07/02/22', 'resting_hr': 52}
# Resting hr is 46.
# {'date': '07/03/22', 'resting_hr': 46}
# Resting hr is 47.
# {'date': '07/04/22', 'resting_hr': 47}
# Resting hr is 46.
# {'date': '07/05/22', 'resting_hr': 46}
# Resting hr is 49.
# {'date': '07/06/22', 'resting_hr': 49}
# Resting hr is 50.
# {'date': '07/07/22', 'resting_hr': 50}
# Resting hr is 51.
# {'date': '07/08/22', 'resting_hr': 51}
# Resting hr is 52.
# {'date': '07/09/22', 'resting_hr': 52}
# Resting hr is 52.
# {'date': '07/10/22', 'resting_hr': 52}
# Resting hr is 46.
# {'date': '07/11/22', 'resting_hr': 46}
# Resting hr is 52.
# {'date': '07/12/22', 'resting_hr': 52}
# Resting hr is 46.
# {'date': '07/13/22', 'resting_hr': 46}
# Resting hr is 47.
# {'date': '07/14/22', 'resting_hr': 47}
# Resting hr is 47.
# {'date': '07/15/22', 'resting_hr': 47}
# Resting hr is 48.
# {'date': '07/16/22', 'resting_hr': 48}
# Resting hr is 50.
# {'date': '07/17/22', 'resting_hr': 50}
# Resting hr is 47.
# {'date': '07/18/22', 'resting_hr': 47}
# Resting hr is 45.
# {'date': '07/19/22', 'resting_hr': 45}
# Resting hr is 45.
# {'date': '07/20/22', 'resting_hr': 45}
# Resting hr is 52.
# {'date': '07/21/22', 'resting_hr': 52}
# Resting hr is 54.
# {'date': '07/22/22', 'resting_hr': 54}
# Resting hr is 55.
# {'date': '07/23/22', 'resting_hr': 55}
# Resting hr is 51.
# {'date': '07/24/22', 'resting_hr': 51}
# Resting hr is 53.
# {'date': '07/25/22', 'resting_hr': 53}
# Resting hr is 48.
# {'date': '07/26/22', 'resting_hr': 48}
# Resting hr is 52.
# {'date': '07/27/22', 'resting_hr': 52}
# Resting hr is 62.
# {'date': '07/28/22', 'resting_hr': 62}
# Resting hr is 50.
# {'date': '07/29/22', 'resting_hr': 50}
# Resting hr is 53.
# {'date': '07/30/22', 'resting_hr': 53}
# Resting hr is 49.
# {'date': '07/31/22', 'resting_hr': 49}
# Resting hr is 56.
# {'date': '08/01/22', 'resting_hr': 56}
# Resting hr is 57.
# {'date': '08/02/22', 'resting_hr': 57}
# Resting hr is 52.
# {'date': '08/03/22', 'resting_hr': 52}
# Resting hr is 52.
# {'date': '08/04/22', 'resting_hr': 52}
# Resting hr is 49.
# {'date': '08/05/22', 'resting_hr': 49}
# Resting hr is 56.
# {'date': '08/06/22', 'resting_hr': 56}
# Resting hr is 51.
# {'date': '08/07/22', 'resting_hr': 51}
# Resting hr is 48.
# {'date': '08/08/22', 'resting_hr': 48}
# Resting hr is 64.
# {'date': '08/09/22', 'resting_hr': 64}
# Resting hr is 51.
# {'date': '08/10/22', 'resting_hr': 51}
# Resting hr is 48.
# {'date': '08/11/22', 'resting_hr': 48}
# Resting hr is 49.
# {'date': '08/12/22', 'resting_hr': 49}
# Resting hr is 52.
# {'date': '08/13/22', 'resting_hr': 52}
# Resting hr is 49.
# {'date': '08/14/22', 'resting_hr': 49}
# Resting hr is 51.
# {'date': '08/15/22', 'resting_hr': 51}
# Resting hr is 52.
# {'date': '08/16/22', 'resting_hr': 52}
# Resting hr is 47.
# {'date': '08/17/22', 'resting_hr': 47}
# Resting hr is 60.
# {'date': '08/18/22', 'resting_hr': 60}
# Resting hr is 55.
# {'date': '08/19/22', 'resting_hr': 55}
# Resting hr is 55.
# {'date': '08/20/22', 'resting_hr': 55}
# Resting hr is 54.
# {'date': '08/21/22', 'resting_hr': 54}
# Resting hr is 54.
# {'date': '08/22/22', 'resting_hr': 54}
# Resting hr is 61.
# {'date': '08/23/22', 'resting_hr': 61}
# Resting hr is 55.
# {'date': '08/24/22', 'resting_hr': 55}
# Resting hr is 52.
# {'date': '08/25/22', 'resting_hr': 52}
# Resting hr is 59.
# {'date': '08/26/22', 'resting_hr': 59}
# Resting hr is 66.
# {'date': '08/27/22', 'resting_hr': 66}
# Resting hr is 53.
# {'date': '08/28/22', 'resting_hr': 53}
# Resting hr is 70.
# {'date': '08/29/22', 'resting_hr': 70}
# Resting hr is 69.
# {'date': '08/30/22', 'resting_hr': 69}
# Resting hr is 55.
# {'date': '08/31/22', 'resting_hr': 55}
# Resting hr is 54.
# {'date': '09/01/22', 'resting_hr': 54}
# Resting hr is 55.
# {'date': '09/02/22', 'resting_hr': 55}
# Resting hr is 52.
# {'date': '09/03/22', 'resting_hr': 52}
# Resting hr is 54.
# {'date': '09/04/22', 'resting_hr': 54}
# Resting hr is 48.
# {'date': '09/05/22', 'resting_hr': 48}
# Resting hr is 49.
# {'date': '09/06/22', 'resting_hr': 49}
# Resting hr is 48.
# {'date': '09/07/22', 'resting_hr': 48}
# Resting hr is 46.
# {'date': '09/08/22', 'resting_hr': 46}
# Resting hr is 49.
# {'date': '09/09/22', 'resting_hr': 49}
# Resting hr is 51.
# {'date': '09/10/22', 'resting_hr': 51}
# Resting hr is 51.
# {'date': '09/11/22', 'resting_hr': 51}
# Resting hr is 51.
# {'date': '09/12/22', 'resting_hr': 51}
# Resting hr is 48.
# {'date': '09/13/22', 'resting_hr': 48}
# Resting hr is 55.
# {'date': '09/14/22', 'resting_hr': 55}
# Resting hr is 49.
# {'date': '09/15/22', 'resting_hr': 49}
# Resting hr is 51.
# {'date': '09/16/22', 'resting_hr': 51}
# Resting hr is 51.
# {'date': '09/17/22', 'resting_hr': 51}
# Resting hr is 54.
# {'date': '09/18/22', 'resting_hr': 54}
# Resting hr is 51.
# {'date': '09/19/22', 'resting_hr': 51}
# Resting hr is 52.
# {'date': '09/20/22', 'resting_hr': 52}
# Resting hr is 55.
# {'date': '09/21/22', 'resting_hr': 55}
# Resting hr is 57.
# {'date': '09/22/22', 'resting_hr': 57}
# Resting hr is 51.
# {'date': '09/23/22', 'resting_hr': 51}
# Resting hr is 50.
# {'date': '09/24/22', 'resting_hr': 50}
# Resting hr is 56.
# {'date': '09/25/22', 'resting_hr': 56}
# Resting hr is 49.
# {'date': '09/26/22', 'resting_hr': 49}
# Resting hr is 50.
# {'date': '09/27/22', 'resting_hr': 50}
# Resting hr is 52.
# {'date': '09/28/22', 'resting_hr': 52}
# Resting hr is 45.
# {'date': '09/29/22', 'resting_hr': 45}
# Resting hr is 48.
# {'date': '09/30/22', 'resting_hr': 48}
# Resting hr is 50.
# {'date': '10/01/22', 'resting_hr': 50}
# Resting hr is 51.
# {'date': '10/02/22', 'resting_hr': 51}
# Resting hr is 48.
# {'date': '10/03/22', 'resting_hr': 48}
# Resting hr is 46.
# {'date': '10/04/22', 'resting_hr': 46}
# Resting hr is 50.
# {'date': '10/05/22', 'resting_hr': 50}
# Resting hr is 48.
# {'date': '10/06/22', 'resting_hr': 48}
# Resting hr is 56.
# {'date': '10/07/22', 'resting_hr': 56}
# Resting hr is 55.
# {'date': '10/08/22', 'resting_hr': 55}
# Resting hr is 58.
# {'date': '10/09/22', 'resting_hr': 58}
# Resting hr is 50.
# {'date': '10/10/22', 'resting_hr': 50}
# Resting hr is 49.
# {'date': '10/11/22', 'resting_hr': 49}
# Resting hr is 51.
# {'date': '10/12/22', 'resting_hr': 51}
# Resting hr is 47.
# {'date': '10/13/22', 'resting_hr': 47}
# Resting hr is 54.
# {'date': '10/14/22', 'resting_hr': 54}
# Resting hr is 56.
# {'date': '10/15/22', 'resting_hr': 56}
# Resting hr is 50.
# {'date': '10/16/22', 'resting_hr': 50}
# Resting hr is 57.
# {'date': '10/17/22', 'resting_hr': 57}
# Resting hr is 51.
# {'date': '10/18/22', 'resting_hr': 51}
# Resting hr is 57.
# {'date': '10/19/22', 'resting_hr': 57}
# Resting hr is 49.
# {'date': '10/20/22', 'resting_hr': 49}
# Resting hr is 56.
# {'date': '10/21/22', 'resting_hr': 56}
# Resting hr is 63.
# {'date': '10/22/22', 'resting_hr': 63}
# Resting hr is 59.
# {'date': '10/23/22', 'resting_hr': 59}
# Resting hr is 51.
# {'date': '10/24/22', 'resting_hr': 51}
# Resting hr is 62.
# {'date': '10/26/22', 'resting_hr': 62}
# Resting hr is 63.
# {'date': '10/26/22', 'resting_hr': 63}
# Resting hr is 52.
# {'date': '10/31/22', 'resting_hr': 52}
# Resting hr is 51.
# {'date': '11/01/22', 'resting_hr': 51}
# Resting hr is 49.
# {'date': '11/02/22', 'resting_hr': 49}
# Resting hr is 48.
# {'date': '11/03/22', 'resting_hr': 48}
# Resting hr is 52.
# {'date': '11/04/22', 'resting_hr': 52}
# Resting hr is 55.
# {'date': '11/05/22', 'resting_hr': 55}
# Resting hr is 51.
# {'date': '11/06/22', 'resting_hr': 51}
# Resting hr is 45.
# {'date': '11/07/22', 'resting_hr': 45}
# Resting hr is 53.
# {'date': '11/08/22', 'resting_hr': 53}
# Resting hr is 51.
# {'date': '11/09/22', 'resting_hr': 51}
# Resting hr is 53.
# {'date': '11/10/22', 'resting_hr': 53}
# Resting hr is 51.
# {'date': '11/11/22', 'resting_hr': 51}
# Resting hr is 54.
# {'date': '11/12/22', 'resting_hr': 54}
# Resting hr is 63.
# {'date': '11/13/22', 'resting_hr': 63}
# Resting hr is 59.
# {'date': '11/14/22', 'resting_hr': 59}
# Resting hr is 59.
# {'date': '11/15/22', 'resting_hr': 59}
# Resting hr is 69.
# {'date': '11/16/22', 'resting_hr': 69}
# Resting hr is 63.
# {'date': '11/17/22', 'resting_hr': 63}
# Resting hr is 57.
# {'date': '11/18/22', 'resting_hr': 57}
# Resting hr is 59.
# {'date': '11/19/22', 'resting_hr': 59}
# Resting hr is 57.
# {'date': '11/20/22', 'resting_hr': 57}
# Resting hr is 63.
# {'date': '11/21/22', 'resting_hr': 63}
# Resting hr is 74.
# {'date': '11/22/22', 'resting_hr': 74}
# Resting hr is 54.
# {'date': '11/23/22', 'resting_hr': 54}
# Resting hr is 56.
# {'date': '11/24/22', 'resting_hr': 56}
# Resting hr is 56.
# {'date': '11/25/22', 'resting_hr': 56}
# Resting hr is 60.
# {'date': '11/26/22', 'resting_hr': 60}
# Resting hr is 56.
# {'date': '11/27/22', 'resting_hr': 56}
# Resting hr is 50.
# {'date': '11/28/22', 'resting_hr': 50}
# Resting hr is 58.
# {'date': '11/29/22', 'resting_hr': 58}
# Resting hr is 54.
# {'date': '11/30/22', 'resting_hr': 54}
# Resting hr is 53.
# {'date': '12/01/22', 'resting_hr': 53}
# Resting hr is 58.
# {'date': '12/02/22', 'resting_hr': 58}
# Resting hr is 66.
# {'date': '12/03/22', 'resting_hr': 66}
# Resting hr is 55.
# {'date': '12/04/22', 'resting_hr': 55}
# Resting hr is 57.
# {'date': '12/05/22', 'resting_hr': 57}
# Resting hr is 52.
# {'date': '12/06/22', 'resting_hr': 52}
# Resting hr is 50.
# {'date': '12/07/22', 'resting_hr': 50}
# Resting hr is 50.
# {'date': '12/08/22', 'resting_hr': 50}
# Resting hr is 50.
# {'date': '12/09/22', 'resting_hr': 50}
# Resting hr is 53.
# {'date': '12/10/22', 'resting_hr': 53}
# Resting hr is 55.
# {'date': '12/11/22', 'resting_hr': 55}
# Resting hr is 52.
# {'date': '12/12/22', 'resting_hr': 52}
# Resting hr is 58.
# {'date': '12/13/22', 'resting_hr': 58}
# Resting hr is 54.
# {'date': '12/14/22', 'resting_hr': 54}
# Resting hr is 57.
# {'date': '12/15/22', 'resting_hr': 57}
# Resting hr is 58.
# {'date': '12/16/22', 'resting_hr': 58}
# Resting hr is 67.
# {'date': '12/17/22', 'resting_hr': 67}
# Resting hr is 63.
# {'date': '12/18/22', 'resting_hr': 63}
# Resting hr is 53.
# {'date': '12/19/22', 'resting_hr': 53}
# Resting hr is 58.
# {'date': '12/20/22', 'resting_hr': 58}
# Resting hr is 54.
# {'date': '12/21/22', 'resting_hr': 54}
# Resting hr is 57.
# {'date': '12/22/22', 'resting_hr': 57}
# Resting hr is 59.
# {'date': '12/23/22', 'resting_hr': 59}
# Resting hr is 55.
# {'date': '12/24/22', 'resting_hr': 55}
# Resting hr is 44.
# {'date': '12/25/22', 'resting_hr': 44}
# Resting hr is 51.
# {'date': '12/26/22', 'resting_hr': 51}
# Resting hr is 55.
# {'date': '12/27/22', 'resting_hr': 55}
# Resting hr is 57.
# {'date': '12/28/22', 'resting_hr': 57}
# Resting hr is 55.
# {'date': '12/29/22', 'resting_hr': 55}
# Resting hr is 61.
# {'date': '12/30/22', 'resting_hr': 61}
# Resting hr is 62.
# {'date': '12/31/22', 'resting_hr': 62}
# Resting hr is 51.
# {'date': '01/01/23', 'resting_hr': 51}
# Resting hr is 64.
# {'date': '01/02/23', 'resting_hr': 64}
# Resting hr is 52.
# {'date': '01/03/23', 'resting_hr': 52}
# Resting hr is 47.
# {'date': '01/04/23', 'resting_hr': 47}
# Resting hr is 51.
# {'date': '01/05/23', 'resting_hr': 51}
# Resting hr is 54.
# {'date': '01/06/23', 'resting_hr': 54}
# Resting hr is 50.
# {'date': '01/07/23', 'resting_hr': 50}
# Resting hr is 48.
# {'date': '01/08/23', 'resting_hr': 48}
# Resting hr is 60.
# {'date': '01/09/23', 'resting_hr': 60}
# Resting hr is 53.
# {'date': '01/10/23', 'resting_hr': 53}
# Resting hr is 59.
# {'date': '01/11/23', 'resting_hr': 59}
# Resting hr is 63.
# {'date': '01/12/23', 'resting_hr': 63}
# Resting hr is 50.
# {'date': '01/13/23', 'resting_hr': 50}
# Resting hr is 56.
# {'date': '01/14/23', 'resting_hr': 56}
# Resting hr is 59.
# {'date': '01/15/23', 'resting_hr': 59}
# Resting hr is 58.
# {'date': '01/16/23', 'resting_hr': 58}
# Resting hr is 52.
# {'date': '01/17/23', 'resting_hr': 52}
# Resting hr is 62.
# {'date': '01/18/23', 'resting_hr': 62}
# Resting hr is 58.
# {'date': '01/19/23', 'resting_hr': 58}
# Resting hr is 55.
# {'date': '01/20/23', 'resting_hr': 55}
# Resting hr is 49.
# {'date': '01/21/23', 'resting_hr': 49}
# Resting hr is 49.
# {'date': '01/22/23', 'resting_hr': 49}
# Resting hr is 50.
# {'date': '01/23/23', 'resting_hr': 50}
# Resting hr is 53.
# {'date': '01/24/23', 'resting_hr': 53}
# Resting hr is 49.
# {'date': '01/25/23', 'resting_hr': 49}
# Resting hr is 51.
# {'date': '01/26/23', 'resting_hr': 51}
# Resting hr is 52.
# {'date': '01/27/23', 'resting_hr': 52}
# Resting hr is 57.
# {'date': '01/28/23', 'resting_hr': 57}
# Resting hr is 50.
# {'date': '01/29/23', 'resting_hr': 50}
# Resting hr is 59.
# {'date': '01/30/23', 'resting_hr': 59}
# Resting hr is 51.
# {'date': '01/31/23', 'resting_hr': 51}
# Resting hr is 48.
# {'date': '02/01/23', 'resting_hr': 48}
# Resting hr is 60.
# {'date': '02/06/23', 'resting_hr': 60}
# Resting hr is 49.
# {'date': '02/07/23', 'resting_hr': 49}
# Resting hr is 53.
# {'date': '02/08/23', 'resting_hr': 53}
# Resting hr is 52.
# {'date': '02/09/23', 'resting_hr': 52}
# Resting hr is 50.
# {'date': '02/10/23', 'resting_hr': 50}
# Resting hr is 56.
# {'date': '02/11/23', 'resting_hr': 56}
# Resting hr is 50.
# {'date': '02/12/23', 'resting_hr': 50}
# Resting hr is 55.
# {'date': '02/13/23', 'resting_hr': 55}
# Resting hr is 49.
# {'date': '02/14/23', 'resting_hr': 49}
# Resting hr is 49.
# {'date': '02/15/23', 'resting_hr': 49}
# Resting hr is 61.
# {'date': '02/16/23', 'resting_hr': 61}
# Resting hr is 54.
# {'date': '02/17/23', 'resting_hr': 54}
# Resting hr is 57.
# {'date': '02/18/23', 'resting_hr': 57}
# Resting hr is 51.
# {'date': '02/19/23', 'resting_hr': 51}
# Resting hr is 48.
# {'date': '02/20/23', 'resting_hr': 48}
# Resting hr is 50.
# {'date': '02/21/23', 'resting_hr': 50}
# Resting hr is 52.
# {'date': '02/22/23', 'resting_hr': 52}
# Resting hr is 53.
# {'date': '02/23/23', 'resting_hr': 53}
# Resting hr is 48.
# {'date': '02/24/23', 'resting_hr': 48}
# Resting hr is 53.
# {'date': '02/25/23', 'resting_hr': 53}
# Resting hr is 46.
# {'date': '02/26/23', 'resting_hr': 46}
# Resting hr is 48.
# {'date': '02/27/23', 'resting_hr': 48}
# Resting hr is 49.
# {'date': '02/28/23', 'resting_hr': 49}
# Resting hr is 47.
# {'date': '03/01/23', 'resting_hr': 47}
# Resting hr is 51.
# {'date': '03/02/23', 'resting_hr': 51}
# Resting hr is 47.
# {'date': '03/03/23', 'resting_hr': 47}
# Resting hr is 52.
# {'date': '03/04/23', 'resting_hr': 52}
# Resting hr is 54.
# {'date': '03/05/23', 'resting_hr': 54}
# Resting hr is 42.
# {'date': '03/06/23', 'resting_hr': 42}
# Resting hr is 53.
# {'date': '03/07/23', 'resting_hr': 53}
# Resting hr is 50.
# {'date': '03/08/23', 'resting_hr': 50}
# Resting hr is 51.
# {'date': '03/09/23', 'resting_hr': 51}
# Resting hr is 45.
# {'date': '03/10/23', 'resting_hr': 45}
# Resting hr is 60.
# {'date': '03/11/23', 'resting_hr': 60}
# Resting hr is 45.
# {'date': '03/12/23', 'resting_hr': 45}
# Resting hr is 50.
# {'date': '03/13/23', 'resting_hr': 50}
