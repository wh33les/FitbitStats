# %% [markdown]
# # Exercise versus

# %%
# To list files in a directory
import os
# Move up in directories
print(os.getcwd()) # for debugging
os.chdir("..")
print(os.getcwd()) # for debugging

# To work with .json files
import json

# To work with .csv files
import pandas as pd

# To parse dates
from datetime import datetime

# To time execution
import time # for debugging
# Out:
# C:\Users\leyjf\Dropbox\github\FitbitStatsProject\CleanedData
# C:\Users\leyjf\Dropbox\github\FitbitStatsProject

# %%
# Load and parse exercise file
exercise_list = open("CleanedData\\exercise_grouped_by_date.json")
#type(exercise_list) # for debugging
parsed_exercise = json.load(exercise_list)
#parsed_exercise # for debugging

# Total exercise per day
for day in parsed_exercise:
    total_minutes = 0
    for i in range(1,len(day)):
        total_minutes = sum((day["exercise"+str(i)]["belowZonesMinutes"],
                            day["exercise"+str(i)]["fatBurnMinutes"],
                            day["exercise"+str(i)]["cardioMinutes"],
                            day["exercise"+str(i)]["peakMinutes"]),
                            total_minutes)
    day["totalMinutes"] = total_minutes    
#parsed_exercise # for debugging
# Out:
# [{'date': '03/15/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 160,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 1,
#    'cardioMinutes': 11,
#    'peakMinutes': 11,
#    'startTime': '03/15/22 10:43:13'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 111,
#    'belowZonesMinutes': 12,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/15/22 15:31:08'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 105,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/15/22 18:06:28'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 112,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/15/22 20:43:32'},
#   'totalMinutes': 83},
#  {'date': '03/16/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 154,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 13,
#    'peakMinutes': 7,
#    'startTime': '03/16/22 11:57:43'},
#   'totalMinutes': 23},
#  {'date': '03/17/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 109,
#    'belowZonesMinutes': 16,
#    'fatBurnMinutes': 7,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/17/22 15:33:46'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 103,
#    'belowZonesMinutes': 20,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/17/22 18:10:49'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 116,
#    'belowZonesMinutes': 9,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/17/22 20:49:34'},
#   'totalMinutes': 72},
#  {'date': '03/20/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 95,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/20/22 16:28:29'},
#   'totalMinutes': 10},
#  {'date': '03/21/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 152,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 15,
#    'peakMinutes': 7,
#    'startTime': '03/21/22 11:49:26'},
#   'totalMinutes': 24},
#  {'date': '03/22/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 146,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 9,
#    'cardioMinutes': 7,
#    'peakMinutes': 6,
#    'startTime': '03/22/22 12:24:09'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 126,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 17,
#    'cardioMinutes': 4,
#    'peakMinutes': 0,
#    'startTime': '03/22/22 14:33:59'},
#   'totalMinutes': 47},
#  {'date': '03/23/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 136,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 10,
#    'peakMinutes': 0,
#    'startTime': '03/23/22 14:35:36'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 126,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 21,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '03/23/22 17:18:36'},
#   'totalMinutes': 51},
#  {'date': '03/28/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 131,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '03/28/22 15:02:24'},
#   'totalMinutes': 19},
#  {'date': '03/29/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 131,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '03/29/22 15:38:05'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 128,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 4,
#    'peakMinutes': 0,
#    'startTime': '03/29/22 20:47:00'},
#   'totalMinutes': 40},
#  {'date': '03/31/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/31/22 18:43:54'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 119,
#    'belowZonesMinutes': 9,
#    'fatBurnMinutes': 17,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/31/22 20:45:59'},
#   'totalMinutes': 44},
#  {'date': '04/04/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 114,
#    'belowZonesMinutes': 9,
#    'fatBurnMinutes': 7,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/04/22 11:46:37'},
#   'totalMinutes': 16},
#  {'date': '04/05/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 128,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/05/22 00:00:48'},
#   'totalMinutes': 11},
#  {'date': '04/07/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 115,
#    'belowZonesMinutes': 13,
#    'fatBurnMinutes': 9,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/07/22 18:51:22'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 107,
#    'belowZonesMinutes': 22,
#    'fatBurnMinutes': 1,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/07/22 20:53:25'},
#   'totalMinutes': 45},
#  {'date': '04/11/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 167,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 11,
#    'peakMinutes': 12,
#    'startTime': '04/11/22 10:52:50'},
#   'totalMinutes': 25},
#  {'date': '04/12/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 159,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 11,
#    'peakMinutes': 8,
#    'startTime': '04/12/22 13:25:41'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 131,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 4,
#    'peakMinutes': 0,
#    'startTime': '04/12/22 15:42:18'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/12/22 17:11:06'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 126,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 23,
#    'cardioMinutes': 6,
#    'peakMinutes': 0,
#    'startTime': '04/12/22 17:56:19'},
#   'exercise5': {'activityName': 'Walk',
#    'averageHeartRate': 127,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/12/22 20:47:52'},
#   'totalMinutes': 121},
#  {'date': '04/14/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 124,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 20,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/14/22 19:03:38'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 124,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 21,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/14/22 20:56:18'},
#   'totalMinutes': 45},
#  {'date': '04/17/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 96,
#    'belowZonesMinutes': 11,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/17/22 17:54:32'},
#   'totalMinutes': 11},
#  {'date': '04/18/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 156,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 8,
#    'cardioMinutes': 7,
#    'peakMinutes': 11,
#    'startTime': '04/18/22 13:04:21'},
#   'totalMinutes': 26},
#  {'date': '04/19/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 125,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '04/19/22 18:55:17'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 131,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 4,
#    'peakMinutes': 0,
#    'startTime': '04/19/22 20:47:56'},
#   'totalMinutes': 38},
#  {'date': '04/20/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 166,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 11,
#    'peakMinutes': 12,
#    'startTime': '04/20/22 15:22:33'},
#   'totalMinutes': 26},
#  {'date': '04/21/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 130,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '04/21/22 18:49:51'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 133,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '04/21/22 20:51:05'},
#   'totalMinutes': 39},
#  {'date': '04/22/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 162,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 13,
#    'peakMinutes': 11,
#    'startTime': '04/22/22 12:09:22'},
#   'totalMinutes': 26},
#  {'date': '04/25/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 153,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 12,
#    'peakMinutes': 5,
#    'startTime': '04/25/22 13:54:10'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 104,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/25/22 19:55:17'},
#   'totalMinutes': 34},
#  {'date': '04/26/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 130,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '04/26/22 15:07:20'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 112,
#    'belowZonesMinutes': 12,
#    'fatBurnMinutes': 8,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/26/22 18:06:04'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '04/26/22 20:49:56'},
#   'totalMinutes': 63},
#  {'date': '04/27/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 153,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 8,
#    'cardioMinutes': 15,
#    'peakMinutes': 2,
#    'startTime': '04/27/22 16:41:40'},
#   'totalMinutes': 25},
#  {'date': '04/30/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '04/30/22 11:31:38'},
#   'exercise2': {'activityName': 'Run',
#    'averageHeartRate': 162,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 13,
#    'peakMinutes': 10,
#    'startTime': '04/30/22 16:31:38'},
#   'totalMinutes': 45},
#  {'date': '05/03/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 159,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 10,
#    'peakMinutes': 3,
#    'startTime': '05/03/22 12:20:31'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 119,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/03/22 17:04:00'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 128,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 13,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '05/03/22 18:08:02'},
#   'totalMinutes': 51},
#  {'date': '05/04/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 140,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 35,
#    'cardioMinutes': 19,
#    'peakMinutes': 3,
#    'startTime': '05/04/22 14:20:21'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 113,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/04/22 19:21:47'},
#   'totalMinutes': 84},
#  {'date': '05/05/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 148,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 18,
#    'peakMinutes': 0,
#    'startTime': '05/05/22 12:36:01'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 126,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '05/05/22 13:36:43'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 120,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/05/22 16:55:37'},
#   'totalMinutes': 60},
#  {'date': '05/06/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 148,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 21,
#    'peakMinutes': 0,
#    'startTime': '05/06/22 13:22:32'},
#   'totalMinutes': 27},
#  {'date': '05/07/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 149,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 23,
#    'peakMinutes': 0,
#    'startTime': '05/07/22 17:41:24'},
#   'totalMinutes': 28},
#  {'date': '05/12/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 128,
#    'belowZonesMinutes': 5,
#    'fatBurnMinutes': 24,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '05/12/22 14:02:49'},
#   'totalMinutes': 31},
#  {'date': '05/14/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 168,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 1,
#    'cardioMinutes': 6,
#    'peakMinutes': 20,
#    'startTime': '05/14/22 12:15:57'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 124,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 41,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/14/22 16:03:56'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 112,
#    'belowZonesMinutes': 9,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/14/22 21:22:42'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 114,
#    'belowZonesMinutes': 5,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/14/22 22:57:26'},
#   'totalMinutes': 95},
#  {'date': '05/16/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 162,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 12,
#    'peakMinutes': 13,
#    'startTime': '05/16/22 13:13:10'},
#   'totalMinutes': 27},
#  {'date': '05/17/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 124,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '05/17/22 16:36:57'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 114,
#    'belowZonesMinutes': 11,
#    'fatBurnMinutes': 7,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '05/17/22 18:21:57'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 124,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/17/22 19:27:41'},
#   'exercise4': {'activityName': 'Run',
#    'averageHeartRate': 158,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 11,
#    'peakMinutes': 14,
#    'startTime': '05/17/22 23:26:56'},
#   'totalMinutes': 85},
#  {'date': '05/18/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 151,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 7,
#    'peakMinutes': 15,
#    'startTime': '05/18/22 12:38:39'},
#   'totalMinutes': 27},
#  {'date': '05/21/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 156,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 5,
#    'peakMinutes': 18,
#    'startTime': '05/21/22 11:45:03'},
#   'totalMinutes': 28},
#  {'date': '05/22/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 104,
#    'belowZonesMinutes': 15,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/22/22 15:32:51'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 104,
#    'belowZonesMinutes': 17,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/22/22 20:00:51'},
#   'totalMinutes': 32},
#  {'date': '05/24/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 113,
#    'belowZonesMinutes': 18,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '05/24/22 16:00:55'},
#   'totalMinutes': 35},
#  {'date': '05/25/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 13,
#    'fatBurnMinutes': 17,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '05/25/22 15:34:18'},
#   'totalMinutes': 35},
#  {'date': '05/26/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 120,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 27,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '05/26/22 15:16:15'},
#   'totalMinutes': 36},
#  {'date': '05/27/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 114,
#    'belowZonesMinutes': 19,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '05/27/22 13:54:01'},
#   'totalMinutes': 39},
#  {'date': '05/30/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 129,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '05/30/22 13:27:58'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 110,
#    'belowZonesMinutes': 19,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/30/22 15:57:21'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 124,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '05/30/22 16:51:59'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/30/22 21:00:21'},
#   'totalMinutes': 81},
#  {'date': '05/31/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 165,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 1,
#    'cardioMinutes': 7,
#    'peakMinutes': 19,
#    'startTime': '05/31/22 12:19:09'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 8,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '05/31/22 13:33:35'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 118,
#    'belowZonesMinutes': 5,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '05/31/22 20:50:35'},
#   'totalMinutes': 67},
#  {'date': '06/01/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 160,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 10,
#    'peakMinutes': 17,
#    'startTime': '06/01/22 12:22:52'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 22,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/01/22 13:36:19'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 110,
#    'belowZonesMinutes': 9,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/01/22 16:09:05'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 116,
#    'belowZonesMinutes': 16,
#    'fatBurnMinutes': 17,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '06/01/22 16:48:22'},
#   'exercise5': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 20,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/01/22 20:01:16'},
#   'totalMinutes': 120},
#  {'date': '06/02/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 162,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 7,
#    'peakMinutes': 19,
#    'startTime': '06/02/22 12:10:08'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 116,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/02/22 19:37:23'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/02/22 21:01:52'},
#   'totalMinutes': 64},
#  {'date': '06/03/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 129,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '06/03/22 13:36:02'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 105,
#    'belowZonesMinutes': 11,
#    'fatBurnMinutes': 1,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/03/22 15:59:26'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 113,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/03/22 16:42:56'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 13,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '06/03/22 20:28:16'},
#   'totalMinutes': 70},
#  {'date': '06/04/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 133,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 13,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '06/04/22 12:28:09'},
#   'totalMinutes': 16},
#  {'date': '06/05/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 9,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/05/22 16:23:38'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 100,
#    'belowZonesMinutes': 11,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/05/22 17:33:37'},
#   'totalMinutes': 21},
#  {'date': '06/06/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 126,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '06/06/22 02:46:38'},
#   'totalMinutes': 15},
#  {'date': '06/07/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 126,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '06/07/22 13:33:43'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 115,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/07/22 15:55:26'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 13,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/07/22 16:39:49'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/07/22 21:01:29'},
#   'totalMinutes': 67},
#  {'date': '06/08/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 123,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '06/08/22 13:35:03'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 106,
#    'belowZonesMinutes': 9,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/08/22 16:07:50'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 107,
#    'belowZonesMinutes': 21,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/08/22 16:52:12'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 8,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/08/22 20:05:58'},
#   'totalMinutes': 80},
#  {'date': '06/09/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 116,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 17,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/09/22 13:38:56'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 111,
#    'belowZonesMinutes': 17,
#    'fatBurnMinutes': 8,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '06/09/22 17:02:52'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 106,
#    'belowZonesMinutes': 18,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/09/22 21:11:12'},
#   'totalMinutes': 74},
#  {'date': '06/10/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 111,
#    'belowZonesMinutes': 18,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/10/22 13:35:12'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 108,
#    'belowZonesMinutes': 13,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/10/22 16:16:33'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 113,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 8,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/10/22 17:29:57'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 114,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 10,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/10/22 20:36:53'},
#   'totalMinutes': 74},
#  {'date': '06/12/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 111,
#    'belowZonesMinutes': 8,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/12/22 16:46:43'},
#   'totalMinutes': 11},
#  {'date': '06/13/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 146,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 16,
#    'peakMinutes': 0,
#    'startTime': '06/13/22 12:17:38'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 20,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/13/22 13:34:33'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 116,
#    'belowZonesMinutes': 5,
#    'fatBurnMinutes': 13,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/13/22 19:04:02'},
#   'totalMinutes': 66},
#  {'date': '06/14/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 141,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 15,
#    'peakMinutes': 0,
#    'startTime': '06/14/22 11:44:33'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 118,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/14/22 13:31:23'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 113,
#    'belowZonesMinutes': 5,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/14/22 21:09:43'},
#   'totalMinutes': 66},
#  {'date': '06/15/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 10,
#    'cardioMinutes': 1,
#    'peakMinutes': 1,
#    'startTime': '06/15/22 13:37:22'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 105,
#    'belowZonesMinutes': 17,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/15/22 20:07:25'},
#   'totalMinutes': 45},
#  {'date': '06/16/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 145,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 9,
#    'cardioMinutes': 19,
#    'peakMinutes': 0,
#    'startTime': '06/16/22 11:18:16'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 112,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/16/22 13:32:19'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 108,
#    'belowZonesMinutes': 8,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/16/22 21:09:43'},
#   'totalMinutes': 69},
#  {'date': '06/17/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 4,
#    'peakMinutes': 0,
#    'startTime': '06/17/22 13:55:32'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 105,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 9,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/17/22 21:25:16'},
#   'totalMinutes': 41},
#  {'date': '06/18/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 148,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 24,
#    'peakMinutes': 0,
#    'startTime': '06/18/22 14:05:41'},
#   'totalMinutes': 28},
#  {'date': '06/20/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 153,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 21,
#    'peakMinutes': 3,
#    'startTime': '06/20/22 14:01:12'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 108,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 8,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/20/22 15:51:24'},
#   'totalMinutes': 42},
#  {'date': '06/21/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 151,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 24,
#    'peakMinutes': 0,
#    'startTime': '06/21/22 11:57:52'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 115,
#    'belowZonesMinutes': 27,
#    'fatBurnMinutes': 29,
#    'cardioMinutes': 1,
#    'peakMinutes': 6,
#    'startTime': '06/21/22 13:33:32'},
#   'totalMinutes': 91},
#  {'date': '06/22/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 127,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 3,
#    'peakMinutes': 2,
#    'startTime': '06/22/22 13:32:40'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 106,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 10,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/22/22 20:04:26'},
#   'totalMinutes': 42},
#  {'date': '06/23/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 145,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 23,
#    'peakMinutes': 0,
#    'startTime': '06/23/22 12:04:30'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 110,
#    'belowZonesMinutes': 18,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/23/22 13:35:50'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 101,
#    'belowZonesMinutes': 14,
#    'fatBurnMinutes': 7,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/23/22 16:14:36'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 103,
#    'belowZonesMinutes': 15,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/23/22 19:00:08'},
#   'exercise5': {'activityName': 'Walk',
#    'averageHeartRate': 104,
#    'belowZonesMinutes': 26,
#    'fatBurnMinutes': 9,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/23/22 21:32:53'},
#   'exercise6': {'activityName': 'Walk',
#    'averageHeartRate': 114,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 24,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/23/22 23:46:00'},
#   'totalMinutes': 152},
#  {'date': '06/24/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 110,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/24/22 18:34:08'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 115,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 13,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '06/24/22 20:34:30'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 107,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/24/22 21:40:10'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 110,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 7,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/24/22 23:13:12'},
#   'totalMinutes': 64},
#  {'date': '06/26/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 104,
#    'belowZonesMinutes': 8,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/26/22 23:04:24'},
#   'totalMinutes': 11},
#  {'date': '06/27/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 101,
#    'belowZonesMinutes': 11,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/27/22 00:32:19'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 110,
#    'belowZonesMinutes': 11,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/27/22 13:36:47'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 106,
#    'belowZonesMinutes': 15,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/27/22 19:55:46'},
#   'exercise4': {'activityName': 'Run',
#    'averageHeartRate': 153,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 18,
#    'peakMinutes': 6,
#    'startTime': '06/27/22 23:27:29'},
#   'totalMinutes': 82},
#  {'date': '06/28/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 162,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 16,
#    'peakMinutes': 13,
#    'startTime': '06/28/22 11:49:13'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '06/28/22 13:33:26'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 108,
#    'belowZonesMinutes': 8,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/28/22 16:26:42'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 113,
#    'belowZonesMinutes': 9,
#    'fatBurnMinutes': 13,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/28/22 21:05:25'},
#   'totalMinutes': 84},
#  {'date': '06/29/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 128,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 4,
#    'peakMinutes': 0,
#    'startTime': '06/29/22 13:33:55'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 120,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '06/29/22 20:05:43'},
#   'exercise3': {'activityName': 'Run',
#    'averageHeartRate': 161,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 1,
#    'cardioMinutes': 15,
#    'peakMinutes': 15,
#    'startTime': '06/29/22 23:40:32'},
#   'totalMinutes': 72},
#  {'date': '07/01/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 144,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 28,
#    'peakMinutes': 0,
#    'startTime': '07/01/22 12:02:17'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 133,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 7,
#    'peakMinutes': 0,
#    'startTime': '07/01/22 13:28:32'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 128,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 13,
#    'cardioMinutes': 4,
#    'peakMinutes': 0,
#    'startTime': '07/01/22 20:35:14'},
#   'totalMinutes': 71},
#  {'date': '07/02/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 132,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 25,
#    'cardioMinutes': 15,
#    'peakMinutes': 0,
#    'startTime': '07/02/22 23:44:31'},
#   'totalMinutes': 40},
#  {'date': '07/06/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 135,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 15,
#    'peakMinutes': 0,
#    'startTime': '07/06/22 13:30:08'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 129,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '07/06/22 17:52:11'},
#   'totalMinutes': 38},
#  {'date': '07/07/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 13,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '07/07/22 13:31:01'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 123,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/07/22 20:53:50'},
#   'totalMinutes': 38},
#  {'date': '07/08/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 138,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 27,
#    'peakMinutes': 0,
#    'startTime': '07/08/22 00:18:20'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 125,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 23,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '07/08/22 13:33:46'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 123,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/08/22 20:20:49'},
#   'exercise4': {'activityName': 'Run',
#    'averageHeartRate': 160,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 1,
#    'cardioMinutes': 12,
#    'peakMinutes': 13,
#    'startTime': '07/08/22 23:56:33'},
#   'totalMinutes': 100},
#  {'date': '07/09/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 146,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 6,
#    'peakMinutes': 16,
#    'startTime': '07/09/22 12:56:48'},
#   'totalMinutes': 29},
#  {'date': '07/11/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 133,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 17,
#    'cardioMinutes': 7,
#    'peakMinutes': 0,
#    'startTime': '07/11/22 13:37:51'},
#   'exercise2': {'activityName': 'Run',
#    'averageHeartRate': 148,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 14,
#    'peakMinutes': 0,
#    'startTime': '07/11/22 17:25:46'},
#   'totalMinutes': 42},
#  {'date': '07/12/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 125,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 4,
#    'peakMinutes': 0,
#    'startTime': '07/12/22 13:35:27'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/12/22 16:52:39'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 130,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '07/12/22 21:09:35'},
#   'totalMinutes': 52},
#  {'date': '07/13/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 164,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 1,
#    'cardioMinutes': 9,
#    'peakMinutes': 18,
#    'startTime': '07/13/22 11:52:32'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 123,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/13/22 13:34:13'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/13/22 20:01:45'},
#   'totalMinutes': 71},
#  {'date': '07/14/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 158,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 10,
#    'peakMinutes': 18,
#    'startTime': '07/14/22 11:55:37'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 127,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '07/14/22 13:35:31'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 116,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 8,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/14/22 16:37:19'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/14/22 19:03:15'},
#   'totalMinutes': 83},
#  {'date': '07/15/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 156,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 24,
#    'peakMinutes': 1,
#    'startTime': '07/15/22 11:56:50'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 125,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '07/15/22 13:35:04'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 105,
#    'belowZonesMinutes': 9,
#    'fatBurnMinutes': 1,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/15/22 20:34:06'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 110,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/15/22 21:57:44'},
#   'totalMinutes': 76},
#  {'date': '07/16/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 109,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/16/22 15:39:20'},
#   'totalMinutes': 10},
#  {'date': '07/18/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '07/18/22 13:32:59'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 130,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 4,
#    'peakMinutes': 0,
#    'startTime': '07/18/22 20:05:39'},
#   'totalMinutes': 43},
#  {'date': '07/19/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 112,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/19/22 13:30:30'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 120,
#    'belowZonesMinutes': 12,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/19/22 16:45:07'},
#   'totalMinutes': 52},
#  {'date': '07/20/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 127,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '07/20/22 13:32:20'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '07/20/22 18:02:09'},
#   'totalMinutes': 39},
#  {'date': '07/21/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 130,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '07/21/22 16:34:19'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 22,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/21/22 19:05:23'},
#   'totalMinutes': 49},
#  {'date': '07/22/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 130,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '07/22/22 13:35:24'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 116,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/22/22 20:26:44'},
#   'totalMinutes': 38},
#  {'date': '07/23/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 107,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/23/22 21:23:47'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 110,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/23/22 23:01:55'},
#   'totalMinutes': 22},
#  {'date': '07/24/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 129,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 10,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '07/24/22 19:55:49'},
#   'totalMinutes': 11},
#  {'date': '07/28/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 145,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 18,
#    'peakMinutes': 0,
#    'startTime': '07/28/22 11:03:31'},
#   'totalMinutes': 30},
#  {'date': '07/31/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 104,
#    'belowZonesMinutes': 10,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '07/31/22 14:55:34'},
#   'totalMinutes': 10},
#  {'date': '08/06/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 111,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '08/06/22 01:28:57'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 119,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 17,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '08/06/22 14:17:30'},
#   'totalMinutes': 33},
#  {'date': '08/15/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 119,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 7,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '08/15/22 17:54:27'},
#   'totalMinutes': 11},
#  {'date': '08/17/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 135,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 6,
#    'peakMinutes': 0,
#    'startTime': '08/17/22 12:29:58'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 132,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 2,
#    'peakMinutes': 1,
#    'startTime': '08/17/22 22:00:57'},
#   'totalMinutes': 33},
#  {'date': '08/18/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 129,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '08/18/22 15:36:32'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 131,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 17,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '08/18/22 16:27:45'},
#   'totalMinutes': 42},
#  {'date': '08/21/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 133,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 40,
#    'cardioMinutes': 16,
#    'peakMinutes': 0,
#    'startTime': '08/21/22 22:24:27'},
#   'totalMinutes': 58},
#  {'date': '08/23/22',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 138,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 35,
#    'cardioMinutes': 31,
#    'peakMinutes': 0,
#    'startTime': '08/23/22 18:14:27'},
#   'totalMinutes': 67},
#  {'date': '08/24/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 131,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 6,
#    'peakMinutes': 0,
#    'startTime': '08/24/22 15:34:50'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 124,
#    'belowZonesMinutes': 14,
#    'fatBurnMinutes': 35,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '08/24/22 17:06:11'},
#   'totalMinutes': 70},
#  {'date': '08/25/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 132,
#    'belowZonesMinutes': 5,
#    'fatBurnMinutes': 23,
#    'cardioMinutes': 9,
#    'peakMinutes': 0,
#    'startTime': '08/25/22 17:08:21'},
#   'totalMinutes': 37},
#  {'date': '08/26/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 126,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 20,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '08/26/22 15:34:57'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 130,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 4,
#    'peakMinutes': 0,
#    'startTime': '08/26/22 18:34:10'},
#   'totalMinutes': 43},
#  {'date': '09/01/22',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 120,
# ...
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 22,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/12/23 20:07:00'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/12/23 21:52:51'},
#   'totalMinutes': 54},
#  {'date': '01/13/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 152,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 25,
#    'peakMinutes': 0,
#    'startTime': '01/13/23 14:20:27'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 126,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 7,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '01/13/23 23:50:01'},
#   'totalMinutes': 41},
#  {'date': '01/16/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 127,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/16/23 00:39:45'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 113,
#    'belowZonesMinutes': 19,
#    'fatBurnMinutes': 7,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/16/23 13:23:50'},
#   'totalMinutes': 38},
#  {'date': '01/17/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 162,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 1,
#    'cardioMinutes': 18,
#    'peakMinutes': 9,
#    'startTime': '01/17/23 16:37:27'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 132,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '01/17/23 20:06:35'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 125,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '01/17/23 23:04:08'},
#   'totalMinutes': 69},
#  {'date': '01/18/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 157,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 3,
#    'cardioMinutes': 22,
#    'peakMinutes': 7,
#    'startTime': '01/18/23 12:52:22'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 120,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 9,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '01/18/23 17:50:14'},
#   'totalMinutes': 45},
#  {'date': '01/19/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 115,
#    'belowZonesMinutes': 9,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/19/23 02:17:55'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 126,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '01/19/23 20:04:39'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 118,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/19/23 21:53:53'},
#   'totalMinutes': 49},
#  {'date': '01/20/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 154,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 21,
#    'peakMinutes': 6,
#    'startTime': '01/20/23 14:00:19'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 115,
#    'belowZonesMinutes': 8,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/20/23 16:22:53'},
#   'totalMinutes': 47},
#  {'date': '01/22/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 114,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/22/23 15:37:44'},
#   'totalMinutes': 11},
#  {'date': '01/23/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 116,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 8,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/23/23 01:02:45'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 118,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 9,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/23/23 19:02:36'},
#   'totalMinutes': 27},
#  {'date': '01/24/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 133,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '01/24/23 20:05:22'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 129,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 6,
#    'peakMinutes': 0,
#    'startTime': '01/24/23 23:02:51'},
#   'totalMinutes': 42},
#  {'date': '01/25/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 144,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 27,
#    'peakMinutes': 0,
#    'startTime': '01/25/23 14:39:25'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 107,
#    'belowZonesMinutes': 32,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/25/23 17:00:17'},
#   'totalMinutes': 71},
#  {'date': '01/26/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 125,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '01/26/23 20:08:15'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 129,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '01/26/23 21:47:14'},
#   'totalMinutes': 37},
#  {'date': '01/27/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 157,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 1,
#    'cardioMinutes': 29,
#    'peakMinutes': 3,
#    'startTime': '01/27/23 14:04:30'},
#   'exercise2': {'activityName': 'Run',
#    'averageHeartRate': 141,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 7,
#    'cardioMinutes': 10,
#    'peakMinutes': 0,
#    'startTime': '01/27/23 19:33:57'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 114,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '01/27/23 20:55:01'},
#   'totalMinutes': 70},
#  {'date': '01/28/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 134,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 11,
#    'peakMinutes': 0,
#    'startTime': '01/28/23 20:17:05'},
#   'totalMinutes': 25},
#  {'date': '01/31/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 135,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 9,
#    'cardioMinutes': 8,
#    'peakMinutes': 0,
#    'startTime': '01/31/23 20:07:44'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '01/31/23 23:01:53'},
#   'totalMinutes': 37},
#  {'date': '02/07/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 150,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 27,
#    'peakMinutes': 1,
#    'startTime': '02/07/23 17:19:24'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 132,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 6,
#    'peakMinutes': 0,
#    'startTime': '02/07/23 20:07:34'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 126,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '02/07/23 23:03:25'},
#   'totalMinutes': 76},
#  {'date': '02/08/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 150,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 8,
#    'cardioMinutes': 25,
#    'peakMinutes': 0,
#    'startTime': '02/08/23 13:55:40'},
#   'totalMinutes': 33},
#  {'date': '02/10/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 158,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 23,
#    'peakMinutes': 6,
#    'startTime': '02/10/23 13:33:04'},
#   'totalMinutes': 29},
#  {'date': '02/14/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 157,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 22,
#    'peakMinutes': 1,
#    'startTime': '02/14/23 15:25:53'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 128,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 13,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '02/14/23 20:11:02'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '02/14/23 23:01:46'},
#   'totalMinutes': 59},
#  {'date': '02/15/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 112,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '02/15/23 22:09:00'},
#   'totalMinutes': 10},
#  {'date': '02/16/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 123,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '02/16/23 20:08:18'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 123,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '02/16/23 21:47:18'},
#   'totalMinutes': 36},
#  {'date': '02/17/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 125,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 10,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '02/17/23 22:15:07'},
#   'totalMinutes': 12},
#  {'date': '02/18/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 8,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '02/18/23 04:36:33'},
#   'totalMinutes': 10},
#  {'date': '02/20/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 113,
#    'belowZonesMinutes': 5,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '02/20/23 23:00:31'},
#   'totalMinutes': 16},
#  {'date': '02/21/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 133,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 14,
#    'peakMinutes': 0,
#    'startTime': '02/21/23 16:29:04'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 111,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 7,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '02/21/23 18:08:07'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 123,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 16,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '02/21/23 20:11:00'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 125,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 3,
#    'peakMinutes': 0,
#    'startTime': '02/21/23 23:03:28'},
#   'totalMinutes': 83},
#  {'date': '02/22/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 152,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 25,
#    'peakMinutes': 4,
#    'startTime': '02/22/23 13:35:04'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 8,
#    'cardioMinutes': 2,
#    'peakMinutes': 0,
#    'startTime': '02/22/23 17:43:24'},
#   'totalMinutes': 46},
#  {'date': '02/23/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 9,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '02/23/23 20:13:32'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 113,
#    'belowZonesMinutes': 8,
#    'fatBurnMinutes': 10,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '02/23/23 21:51:39'},
#   'totalMinutes': 27},
#  {'date': '02/24/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 156,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 14,
#    'peakMinutes': 8,
#    'startTime': '02/24/23 13:36:36'},
#   'totalMinutes': 26},
#  {'date': '02/26/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 129,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 19,
#    'cardioMinutes': 5,
#    'peakMinutes': 0,
#    'startTime': '02/26/23 22:20:27'},
#   'totalMinutes': 24},
#  {'date': '02/27/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 152,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 19,
#    'peakMinutes': 3,
#    'startTime': '02/27/23 13:54:58'},
#   'totalMinutes': 26},
#  {'date': '02/28/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 122,
#    'belowZonesMinutes': 3,
#    'fatBurnMinutes': 6,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '02/28/23 13:55:54'},
#   'exercise2': {'activityName': 'Run',
#    'averageHeartRate': 160,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 0,
#    'cardioMinutes': 19,
#    'peakMinutes': 9,
#    'startTime': '02/28/23 14:06:09'},
#   'exercise3': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 17,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '02/28/23 20:11:22'},
#   'exercise4': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 13,
#    'cardioMinutes': 1,
#    'peakMinutes': 0,
#    'startTime': '02/28/23 23:02:03'},
#   'totalMinutes': 73},
#  {'date': '03/01/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 155,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 2,
#    'cardioMinutes': 16,
#    'peakMinutes': 10,
#    'startTime': '03/01/23 13:42:40'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 112,
#    'belowZonesMinutes': 14,
#    'fatBurnMinutes': 18,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/01/23 16:57:15'},
#   'totalMinutes': 61},
#  {'date': '03/02/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 121,
#    'belowZonesMinutes': 1,
#    'fatBurnMinutes': 17,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/02/23 20:07:03'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 117,
#    'belowZonesMinutes': 2,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/02/23 21:52:51'},
#   'totalMinutes': 35},
#  {'date': '03/03/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 157,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 5,
#    'cardioMinutes': 13,
#    'peakMinutes': 12,
#    'startTime': '03/03/23 13:46:38'},
#   'totalMinutes': 30},
#  {'date': '03/04/23',
#   'exercise1': {'activityName': 'Run',
#    'averageHeartRate': 144,
#    'belowZonesMinutes': 0,
#    'fatBurnMinutes': 4,
#    'cardioMinutes': 20,
#    'peakMinutes': 0,
#    'startTime': '03/04/23 16:45:07'},
#   'totalMinutes': 24},
#  {'date': '03/08/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 115,
#    'belowZonesMinutes': 11,
#    'fatBurnMinutes': 23,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/08/23 18:10:26'},
#   'totalMinutes': 34},
#  {'date': '03/09/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 114,
#    'belowZonesMinutes': 4,
#    'fatBurnMinutes': 14,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/09/23 20:07:00'},
#   'exercise2': {'activityName': 'Walk',
#    'averageHeartRate': 115,
#    'belowZonesMinutes': 6,
#    'fatBurnMinutes': 12,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/09/23 21:46:01'},
#   'totalMinutes': 36},
#  {'date': '03/12/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 107,
#    'belowZonesMinutes': 20,
#    'fatBurnMinutes': 11,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/12/23 19:13:31'},
#   'totalMinutes': 31},
#  {'date': '03/13/23',
#   'exercise1': {'activityName': 'Walk',
#    'averageHeartRate': 113,
#    'belowZonesMinutes': 7,
#    'fatBurnMinutes': 15,
#    'cardioMinutes': 0,
#    'peakMinutes': 0,
#    'startTime': '03/13/23 18:35:34'},
#   'totalMinutes': 22}]

# %% [markdown]
# # Exercise versus resting heartrate

# %%
# Load sleep scores
sleep_scores = pd.read_csv("RawData\\ConsolidatedData\\sleep_score.csv", index_col = [0])
#sleep_scores # for debugging

# Match date format
for date in sleep_scores["timestamp"]:
    #print(date) # for debugging
    parsed_date = datetime.strptime(date, "%Y-%m-%dT%H:%M:%SZ").strftime('%m/%d/%y')
    #print(parsed_date) # for debugging
    sleep_scores["timestamp"] = sleep_scores["timestamp"].replace(date, parsed_date)
#sleep_scores # for debugging

# Replace multiple rows with the same date with the averages
averaged_sleep_scores = sleep_scores.groupby(["timestamp"]).mean()
#averaged_sleep_scores # for debugging

# New .json with date, total exercise, resting heartrate
averaged_sleep_scores_string = averaged_sleep_scores.to_json()
averaged_sleep_scores_json = json.loads(averaged_sleep_scores_string)
print(averaged_sleep_scores_json) # for debugging
#print(type(averaged_sleep_scores_json)) # for debugging
resting_hr_v_exercise = []
for entry in parsed_exercise:
    new_entry = {
        "date" : entry["date"],
        "resting_hr" : averaged_sleep_scores_json["resting_heart_rate"]["03/15/22"],
        "total_exercise" : entry["totalMinutes"]
    }
    print(new_entry)
# Out:
# {'sleep_log_entry_id': {'01/01/23': 39636858530.0, '01/02/23': 39652442025.0, '01/03/23': 39665322584.0, '01/04/23': 39676055578.0, '01/05/23': 39693336039.5, '01/06/23': 39705070044.0, '01/07/23': 39717212839.0, '01/08/23': 39723889828.0, '01/09/23': 39742103591.0, '01/10/23': 39755128505.0, '01/11/23': 39764439449.0, '01/12/23': 39779389774.0, '01/13/23': 39790243492.0, '01/14/23': 39803762739.0, '01/15/23': 39812383478.0, '01/16/23': 39827842174.0, '01/17/23': 39836496823.0, '01/18/23': 39850002417.0, '01/19/23': 39865601900.0, '01/20/23': 39876727939.0, '01/21/23': 39891268690.5, '01/22/23': 39901136585.0, '01/23/23': 39915316001.0, '01/24/23': 39932020754.0, '01/25/23': 39941481140.0, '01/26/23': 39957670345.0, '01/27/23': 39965043410.0, '01/28/23': 39980836219.0, '01/29/23': 39990591108.0, '01/31/23': 40017524004.0, '02/01/23': 40028713974.0, '02/08/23': 40118175578.0, '02/09/23': 40135160672.5, '02/10/23': 40144177573.0, '02/11/23': 40161521502.5, '02/12/23': 40170221053.0, '02/13/23': 40187126260.0, '02/14/23': 40195076897.0, '02/15/23': 40210806599.0, '02/16/23': 40225961940.0, '02/17/23': 40240105995.0, '02/18/23': 40253344394.0, '02/19/23': 40263405938.0, '02/20/23': 40277493925.0, '02/21/23': 40286887151.0, '02/22/23': 40299594139.0, '02/23/23': 40311854846.0, '02/24/23': 40324916662.0, '02/25/23': 40340583853.0, '02/26/23': 40350777685.0, '02/27/23': 40360973281.0, '02/28/23': 40377008022.0, '03/01/23': 40388054628.0, '03/02/23': 40400642734.0, '03/03/23': 40416324850.0, '03/04/23': 40430941927.0, '03/05/23': 40441888570.0, '03/06/23': 40458312166.0, '03/07/23': 40480671318.5, '03/08/23': 40490150704.0, '03/09/23': 40502611854.5, '03/10/23': 40514105184.0, '03/11/23': 40528049175.0, '03/12/23': 40538116210.0, '03/13/23': 40548889302.0, '03/16/22': 36119555423.0, '03/17/22': 36128500609.0, '03/18/22': 36149357958.5, '03/19/22': 36155744251.0, '03/20/22': 36173133510.0, '03/21/22': 36177684217.0, '03/22/22': 36200893825.0, '03/23/22': 36210926487.0, '03/24/22': 36229321438.5, '03/25/22': 36239998630.0, '03/27/22': 36259681748.0, '03/28/22': 36278794755.0, '03/29/22': 36289783292.0, '03/30/22': 36303638986.0, '03/31/22': 36319931450.0, '04/01/22': 36325618666.0, '04/02/22': 36341413166.0, '04/03/22': 36355066696.0, '04/04/22': 36367460667.0, '04/06/22': 36391846315.0, '04/07/22': 36411533048.0, '04/08/22': 36425227226.0, '04/09/22': 36436910316.0, '04/10/22': 36451852872.0, '04/11/22': 36458900777.0, '04/12/22': 36467881208.0, '04/13/22': 36490109419.0, '04/14/22': 36501104774.0, '04/15/22': 36515006262.0, '04/16/22': 36527593776.0, '04/17/22': 36539025337.0, '04/18/22': 36550839437.0, '04/19/22': 36566942854.0, '04/20/22': 36581567525.0, '04/21/22': 36585501907.0, '04/22/22': 36601498927.0, '04/23/22': 36617218561.0, '04/24/22': 36626850657.0, '04/25/22': 36640484768.0, '04/26/22': 36654319816.0, '04/27/22': 36669407621.0, '04/28/22': 36683919689.0, '04/29/22': 36695098854.0, '04/30/22': 36701878328.0, '05/01/22': 36718501664.0, '05/02/22': 36731667919.0, '05/03/22': 36744704922.0, '05/04/22': 36758972732.0, '05/05/22': 36769448742.0, '05/06/22': 36781326701.0, '05/07/22': 36792618845.0, '05/08/22': 36810399097.0, '05/09/22': 36813101380.0, '05/10/22': 36834687033.5, '05/11/22': 36842161497.0, '05/12/22': 36855953495.0, '05/13/22': 36867991789.0, '05/14/22': 36880399786.0, '05/15/22': 36892822353.0, '05/16/22': 36904070356.0, '05/17/22': 36917659386.0, '05/18/22': 36930297104.0, '05/19/22': 36944928368.0, '05/20/22': 36963039648.5, '05/21/22': 36965431175.0, '05/22/22': 36982735486.0, '05/23/22': 36996873455.0, '05/24/22': 37011523757.0, '05/25/22': 37022407157.0, '05/26/22': 37035256703.0, '05/27/22': 37046923932.0, '05/28/22': 37061196497.0, '05/29/22': 37070586257.0, '05/30/22': 37081191936.0, '05/31/22': 37094483933.0, '06/01/22': 37109078319.0, '06/02/22': 37119628837.0, '06/03/22': 37131969019.0, '06/04/22': 37142723000.0, '06/05/22': 37150167881.0, '06/06/22': 37168097006.0, '06/07/22': 37180865872.0, '06/08/ ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [70], in <cell line: 23>()
#      22 sleep_scores_v_exercise = []
#      23 for entry in parsed_exercise:
#      24     new_entry = {
#      25         "date" : entry["date"],
# ---> 26         "resting_hr" : averaged_sleep_scores_json["resting_heart_rate"]["03/15/22"],
#      27         "total_exercise" : entry["totalMinutes"]
#      28     }
#      29     print(new_entry)
#
# KeyError: '03/15/22'
